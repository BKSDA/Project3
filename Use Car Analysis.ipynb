# %%
#Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import isnan
import seaborn as sns

# %%
#Importing dataset for analysis
df_user_car_data = pd.read_csv('UserCarData.csv')

# %%
#Checking importation was successful
df_user_car_data
# Out:
#       Sales_ID     name  year  selling_price  km_driven   Region
# 0            1   Maruti  2014         450000     145500     East  \
# 1            2    Skoda  2014         370000     120000     East
# 2            3    Honda  2006         158000     140000  Central
# 3            4  Hyundai  2010         225000     127000  Central
# 4            5   Maruti  2007         130000     120000     East
# ...        ...      ...   ...            ...        ...      ...
# 7901      8124  Hyundai  2013         320000     110000  Central
# 7902      8125  Hyundai  2007         135000     119000  Central
# 7903      8126   Maruti  2009         382000     120000  Central
# 7904      8127     Tata  2013         290000      25000     East
# 7905      8128     Tata  2013         290000      25000     East
#
#          State or Province           City    fuel seller_type transmission
# 0     District of Columbia     Washington  Diesel  Individual       Manual  \
# ...

# %%
#Check the shape for number of columns and rows
df_user_car_data.shape
# Out:
# (7906, 18)

# %%
#Check data types for each column
df_user_car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7906 entries, 0 to 7905
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sales_ID           7906 non-null   int64
#  1   name               7906 non-null   object
#  2   year               7906 non-null   int64
#  3   selling_price      7906 non-null   int64
#  4   km_driven          7906 non-null   int64
#  5   Region             7906 non-null   object
#  6   State or Province  7906 non-null   object
#  7   City               7906 non-null   object
#  8   fuel               7906 non-null   object
#  9   seller_type        7906 non-null   object
#  10  transmission       7906 non-null   object
#  11  owner              7906 non-null   object
#  12  mileage            7906 non-null   float64
#  13  engine             7906 non-null   int64
#  14  max_power          7906 non-null   float64
#  15  torque             7906 non-null   object
# ...

# %%
#Obtain basic statistical measures
df_user_car_data.describe()
# Out:
#           Sales_ID         year  selling_price     km_driven      mileage
# count  7906.000000  7906.000000   7.906000e+03  7.906000e+03  7906.000000  \
# mean   4070.106248  2013.983936   6.498137e+05  6.918866e+04    19.419861
# std    2345.770159     3.863695   8.135827e+05  5.679230e+04     4.036263
# min       1.000000  1994.000000   2.999900e+04  1.000000e+00     0.000000
# 25%    2037.250000  2012.000000   2.700000e+05  3.500000e+04    16.780000
# 50%    4076.500000  2015.000000   4.500000e+05  6.000000e+04    19.300000
# 75%    6102.000000  2017.000000   6.900000e+05  9.542500e+04    22.320000
# max    8128.000000  2020.000000   1.000000e+07  2.360457e+06    42.000000
#
#             engine    max_power        seats
# count  7906.000000  7906.000000  7906.000000
# mean   1458.708829    91.587374     5.416393
# std     503.893057    35.747216     0.959208
# min     624.000000    32.800000     2.000000
# 25%    1197.000000    68.050000     5.000000
# ...

# %%
#Question 1= How many cars were sold each year?
Q1_number_cars_sold_per_year = df_user_car_data.groupby(
    ['year']).count()['Sales_ID']
Q1_number_cars_sold_per_year.plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
#ANSWER1: 2017 was the year with most cars sold.

# %%
#Question2= Which year had the most total sales?
Q2_sales_total_per_year = df_user_car_data.groupby(
    ['year']).sum()['selling_price']
Q2_sales_total_per_year
# Out:
# year
# 1994        144000
# 1995         55000
# 1996         82000
# 1997        774999
# 1998        521000
# 1999       1077000
# 2000       1146914
# 2001        279000
# 2002       1971999
# 2003       3758198
# 2004       5579855
# 2005      10925499
# 2006      17387148
# 2007      30985433
# 2008      41317516
# 2009      52854989
# 2010     102753987
# 2011     183594976
# 2012     219301977
# 2013     307723967
# 2014     320338960
# 2015     462496959
# 2016     599471972
# 2017     899094968
# 2018     772295980
# 2019    1035982984
# 2020      65509997
# Name: selling_price, dtype: int64

# %%
Q2_sales_total_per_year = df_user_car_data.groupby(
    ['year']).sum()['selling_price']
Q2_sales_total_per_year.plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
#ANSWER2= 2019 was the year with more total sales.

# %%
#Question3= Which state sold most cars per year?
sales_per_year_state = df_user_car_data.groupby(
    ['year','State or Province']).count()['Sales_ID'].unstack()
sales_per_year_state
# Out:
# State or Province  Alabama  Arizona  Arkansas  California  Colorado
# year
# 1994                   NaN      NaN       NaN         NaN       NaN  \
# 1995                   NaN      NaN       NaN         NaN       NaN
# 1996                   NaN      NaN       NaN         NaN       NaN
# 1997                   NaN      1.0       NaN         NaN       NaN
# 1998                   NaN      NaN       NaN         NaN       NaN
# 1999                   1.0      NaN       NaN         3.0       NaN
# 2000                   NaN      NaN       NaN         3.0       NaN
# 2001                   NaN      NaN       NaN         1.0       NaN
# 2002                   NaN      NaN       NaN         4.0       NaN
# 2003                   NaN      NaN       NaN         3.0       1.0
# 2004                   NaN      1.0       NaN         7.0       NaN
# 2005                   1.0      2.0       1.0         7.0       NaN
# 2006                   1.0      3.0       1.0        15.0       1.0
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(sales_per_year_state,
            cmap=sns.cubehelix_palette(as_cmap=True))
# Out:
# <Axes: xlabel='State or Province', ylabel='year'>

# %%
#ANSWER3 = California has been selling more cars from 2010 till 2020.

# %%
# Question4 = Which cars are more popular for selling?
name_sales_count_per_year = df_user_car_data.groupby(
    ['year','name']).count()['Sales_ID'].unstack()
name_sales_count_per_year
# Out:
# name  Ambassador  Ashok  Audi   BMW  Chevrolet  Daewoo  Datsun  Fiat  Force
# year
# 1994         1.0    NaN   NaN   NaN        NaN     NaN     NaN   NaN    NaN  \
# 1995         NaN    NaN   NaN   NaN        NaN     NaN     NaN   NaN    NaN
# 1996         NaN    NaN   NaN   NaN        NaN     NaN     NaN   NaN    NaN
# 1997         NaN    NaN   NaN   NaN        NaN     NaN     NaN   NaN    NaN
# 1998         NaN    NaN   NaN   NaN        NaN     NaN     NaN   NaN    NaN
# 1999         NaN    NaN   NaN   NaN        NaN     NaN     NaN   NaN    NaN
# 2000         1.0    NaN   NaN   NaN        NaN     2.0     NaN   NaN    NaN
# 2001         NaN    NaN   NaN   NaN        NaN     1.0     NaN   NaN    NaN
# 2002         NaN    NaN   NaN   NaN        NaN     NaN     NaN   NaN    NaN
# 2003         NaN    NaN   NaN   NaN        NaN     NaN     NaN   NaN    NaN
# 2004         NaN    NaN   NaN   NaN        NaN     NaN     NaN   NaN    NaN
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(name_sales_count_per_year,
            cmap=sns.cubehelix_palette(as_cmap=True))
# Out:
# <Axes: xlabel='name', ylabel='year'>

# %%
#ANSWER4: Maruti are the most popular cars for selling.

# %%
#Question5= Which cars sold generate higher sales prices?
name_sales_amount_per_year = df_user_car_data.groupby(
    ['year','name']).sum()['selling_price'].unstack()
name_sales_amount_per_year
# Out:
# name  Ambassador     Ashok        Audi          BMW   Chevrolet    Daewoo
# year
# 1994     99000.0       NaN         NaN          NaN         NaN       NaN  \
# 1995         NaN       NaN         NaN          NaN         NaN       NaN
# 1996         NaN       NaN         NaN          NaN         NaN       NaN
# 1997         NaN       NaN         NaN          NaN         NaN       NaN
# 1998         NaN       NaN         NaN          NaN         NaN       NaN
# 1999         NaN       NaN         NaN          NaN         NaN       NaN
# 2000     75000.0       NaN         NaN          NaN         NaN  186000.0
# 2001         NaN       NaN         NaN          NaN         NaN   45000.0
# 2002         NaN       NaN         NaN          NaN         NaN       NaN
# 2003         NaN       NaN         NaN          NaN         NaN       NaN
# 2004         NaN       NaN         NaN          NaN         NaN       NaN
# 2005         NaN       NaN         NaN          NaN    160000.0       NaN
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(name_sales_amount_per_year,  
            cmap=sns.cubehelix_palette(as_cmap=True))
# Out:
# <Axes: xlabel='name', ylabel='year'>

# %%
#ANSWER5 = BMWs in 2019, Jaguar in 2017, Lexus second best in 2019.

# %%
#QUESTION6= What portion of the market belongs to each region in relation to sales amount? 
region_sales = df_user_car_data.groupby(
    ['Region']).sum()['selling_price']
region_sales
# Out:
# Region
# Central    1515218334
# East       1221890402
# South      1163745398
# West       1236573143
# Name: selling_price, dtype: int64

# %%
region_sales.plot.pie(ylabel= '' , title="Total Sales per Region", legend=False,
                   autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Total Sales per Region'}>

# %%
#ANSWER6 = The central region has the highest portion of the market,
#yet, the the % is distributed evenly through the whole country.

# %%
df_user_car_data
# Out:
#       Sales_ID     name  year  selling_price  km_driven   Region
# 0            1   Maruti  2014         450000     145500     East  \
# 1            2    Skoda  2014         370000     120000     East
# 2            3    Honda  2006         158000     140000  Central
# 3            4  Hyundai  2010         225000     127000  Central
# 4            5   Maruti  2007         130000     120000     East
# ...        ...      ...   ...            ...        ...      ...
# 7901      8124  Hyundai  2013         320000     110000  Central
# 7902      8125  Hyundai  2007         135000     119000  Central
# 7903      8126   Maruti  2009         382000     120000  Central
# 7904      8127     Tata  2013         290000      25000     East
# 7905      8128     Tata  2013         290000      25000     East
#
#          State or Province           City    fuel seller_type transmission
# 0     District of Columbia     Washington  Diesel  Individual       Manual  \
# ...

# %%
#Question7= How many owners do cars have prior to selling based on name of car?
plt.figure(figsize=(20, 10))
sns.scatterplot(x= 'owner',
                y= 'name',
                hue='year',
                data=df_user_car_data)
# Out:
# <Axes: xlabel='owner', ylabel='name'>

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(x= 'km_driven',
                y= 'owner',
                hue='transmission',
                data=df_user_car_data)
# Out:
# <Axes: xlabel='km_driven', ylabel='owner'>

# %%
#Comparing multiple variables with seaborn
plt.figure(figsize=(50, 10))
sns.pairplot(df_user_car_data, vars=[
    'km_driven','year', 'name', 'owner'])
plt.show()

# %%
owner_numberofsales = df_user_car_data.query(
    "owner != 'First_Owner'").groupby(
    "owner")['Sales_ID'].agg(['mean','count']).query(
        'count >= 100')
display(owner_numberofsales)
owner_numberofsales.plot()
# Out:
#                            mean  count
# owner
# Fourth_Above_Owner  3894.762500    160
# Second_Owner        4115.983135   2016
# Third_Owner         4064.725490    510
# <Axes: xlabel='owner'>

# %%
maruti_sales = df_user_car_data.query("name == 'Maruti'").groupby(
    "year")['selling_price'].agg(['mean','sum']).query(
        'sum >= 500000')
display(maruti_sales)
maruti_sales.plot()
# Out:
#                mean        sum
# year
# 1997   86111.000000     774999
# 1999   56545.454545     622000
# 2000   64091.400000     640914
# 2002  100666.666667    1510000
# 2003   75054.454545    1651198
# 2004   77280.535714    2163855
# 2005   93111.111111    3352000
# 2006  116151.139535    4994499
# 2007  121603.174603    7661000
# 2008  150983.540984    9209996
# 2009  183340.593407   16683994
# 2010  210075.630252   24999000
# 2011  238674.747967   29356994
# 2012  303588.575949   47966995
# 2013  362544.450262   69245990
# 2014  406723.429412   69142983
# 2015  462981.266355   99077991
# 2016  506081.938525  123483993
# 2017  574549.447099  168342988
# 2018  649481.711679  177957989
# 2019  642204.190141   91192995
# 2020  522060.545455   17227998
# <Axes: xlabel='year'>
